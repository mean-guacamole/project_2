# %%
import pandas as pd
import json
import requests

# %%
response = pd.read_json('tweet.json')

# %%
tweet_df
# Out:
#                                                  0    \
# 0  {'date': 1609942590000, 'favorites': '458141',...
#
#                                                  1    \
# 0  {'date': 1604299903000, 'favorites': '92746', ...
#
#                                                  2    \
# 0  {'date': 1604231375000, 'favorites': '124689',...
#
#                                                  3    \
# 0  {'date': 1604084613000, 'favorites': '44842', ...
#
#                                                  4    \
# 0  {'date': 1603037689000, 'favorites': 62414, 'i...
#
#                                                  5    \
# 0  {'date': 1602377246000, 'favorites': 34952, 'i...
#
#                                                  6    \
# 0  {'date': 1601996447000, 'favorites': 58201, 'i...
#
#                                                  7    \
# 0  {'date': 1601032974000, 'favorites': 43281, 'i...
#
#                                                  8    \
# ...
